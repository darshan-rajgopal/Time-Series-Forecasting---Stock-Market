# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn.metrics import mean_absolute_error as mae
from pandas.tseries.offsets import BDay

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14494480343520806349
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11320098816
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1229225032833911937
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
#  xla_global_id: 416903419]

# %%
df_main = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Stock Market/RELIANCE.csv')
df_main.head()
# Out:
#          Date    Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2000-01-03  RELIANCE     EQ      233.05  237.50  251.70  237.50  251.70
# 1  2000-01-04  RELIANCE     EQ      251.70  258.40  271.85  251.30  271.85
# 2  2000-01-05  RELIANCE     EQ      271.85  256.65  287.90  256.65  286.75
# 3  2000-01-06  RELIANCE     EQ      282.50  289.00  300.70  289.00  293.50
# 4  2000-01-07  RELIANCE     EQ      294.35  295.00  317.90  293.00  314.50
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  251.70  249.37   4456424  1.111319e+14     NaN                 NaN
# 1  271.85  263.52   9487878  2.500222e+14     NaN                 NaN
# 2  282.50  274.79  26833684  7.373697e+14     NaN                 NaN
# 3  294.35  295.45  15682286  4.633254e+14     NaN                 NaN
# 4  314.55  308.91  19870977  6.138388e+14     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df_main.drop(['Trades','Deliverable Volume','%Deliverble'],axis=1,inplace=True)

# %%
df_main.shape
# Out:
# (5306, 12)

# %%
time = pd.date_range(start='2000-01-03',periods=5306,freq=BDay())
df_main['time_stamp'] = pd.DataFrame(time)
df_main.drop(['Date'],axis=1,inplace=True)
df_main = df_main.set_index('time_stamp')

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5306 entries, 2000-01-03 to 2020-05-04
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      5306 non-null   object
#  1   Series      5306 non-null   object
#  2   Prev Close  5306 non-null   float64
#  3   Open        5306 non-null   float64
#  4   High        5306 non-null   float64
#  5   Low         5306 non-null   float64
#  6   Last        5306 non-null   float64
#  7   Close       5306 non-null   float64
#  8   VWAP        5306 non-null   float64
#  9   Volume      5306 non-null   int64
#  10  Turnover    5306 non-null   float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 497.4+ KB

# %%
df = df_main[['Close']]

# %%
df.head()
# Out:
#              Close
# time_stamp
# 2000-01-03  251.70
# 2000-01-04  271.85
# 2000-01-05  282.50
# 2000-01-06  294.35
# 2000-01-07  314.55

# %%
df.tail()
# Out:
#               Close
# time_stamp
# 2020-04-28  1937.85
# 2020-04-29  1988.65
# 2020-04-30  1997.30
# 2020-05-01  2024.05
# 2020-05-04  1994.50

# %%
plt.rcParams['figure.figsize'] = [15,8]

# %%
plt.plot(df,color='black')
plt.title('Daily Reliance Stock Price',fontsize=20)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Units',fontsize=15)
plt.show()

# %%
def convert2matrix(data_arr, look_back):
    X, Y =[], []
    for i in range(len(data_arr)-look_back):
        d=i+look_back  
        X.append(data_arr[i:d,0])
        Y.append(data_arr[d,0])
    return np.array(X), np.array(Y)

# %%
from sklearn.preprocessing import MinMaxScaler
#create numpy.ndarray 
df['Close'] = df['Close'].astype(np.float32)
df_arr = df.values
df_arr = np.reshape(df_arr, (-1, 1))
scaler = MinMaxScaler(feature_range=(0.1, 1))
df_arr = scaler.fit_transform(df_arr)

# %%
#Split data set into testing dataset and train dataset
train_size = 4775
train, test =df_arr[0:train_size,:], df_arr[train_size:len(df_arr),:]
# setup look_back window 
look_back = 4
#convert dataset into right shape in order to input into the DNN
trainX, trainY = convert2matrix(train, look_back)
testX, testY = convert2matrix(test, look_back)
# reshape input to be [samples, window size, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (4771, 1, 4)
# (4771,)
# (527, 1, 4)
# (527,)

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 133 kB 8.8 MB/s

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(SimpleRNN(hp.Int('rnn_layer_1',min_value=8,max_value=256,step=8), activation="relu", input_shape=(1,look_back),recurrent_dropout = hp.Choice("recurrent_dropout",[0.2,0.3,0.4],default=0.2)))
    model.add(Dense(hp.Int('dense_layer_1',min_value=8,max_value=256,step=8),activation="relu"))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
             hp.Float('learning_rate', min_value=1e-3, max_value=1e-1, sampling="log")),
        loss='mape',
        metrics=['mape'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mape',
    max_trials=10,
    executions_per_trial=1,
    directory='project',
    project_name='loa_em_3')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 5
# rnn_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# recurrent_dropout (Choice)
# {'default': 0.2, 'conditions': [], 'values': [0.2, 0.3, 0.4], 'ordered': True}
# dense_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# Dropout_rate (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.5, 'step': 0.1, 'sampling': None}
# learning_rate (Float)
# {'default': 0.001, 'conditions': [], 'min_value': 0.001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}

# %%
tuner.search(trainX, trainY,
             epochs=200,
             batch_size=35,
             validation_data=(testX, testY))
# Out:
# Trial 10 Complete [00h 01m 30s]
# val_mape: 1.4559770822525024
#
# Best val_mape So Far: 1.4449316263198853
# Total elapsed time: 00h 17m 47s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/loa_em_3
# Showing 10 best trials
# Objective(name='val_mape', direction='min')
# Trial summary
# Hyperparameters:
# rnn_layer_1: 168
# recurrent_dropout: 0.3
# dense_layer_1: 88
# Dropout_rate: 0.0
# learning_rate: 0.0019397829726650643
# Score: 1.4449316263198853
# Trial summary
# Hyperparameters:
# rnn_layer_1: 136
# recurrent_dropout: 0.3
# dense_layer_1: 56
# Dropout_rate: 0.0
# learning_rate: 0.018144908224752638
# Score: 1.447052001953125
# Trial summary
# Hyperparameters:
# rnn_layer_1: 232
# recurrent_dropout: 0.4
# dense_layer_1: 136
# Dropout_rate: 0.2
# learning_rate: 0.0016082664750335192
# Score: 1.450911521911621
# Trial summary
# Hyperparameters:
# rnn_layer_1: 128
# recurrent_dropout: 0.4
# dense_layer_1: 88
# Dropout_rate: 0.1
# learning_rate: 0.0018774696705689475
# Score: 1.4559770822525024
# Trial summary
# Hyperparameters:
# rnn_layer_1: 32
# recurrent_dropout: 0.4
# dense_layer_1: 160
# Dropout_rate: 0.2
# learning_rate: 0.011425812573577809
# Score: 1.4612125158309937
# Trial summary
# Hyperparameters:
# rnn_layer_1: 208
# recurrent_dropout: 0.4
# dense_layer_1: 88
# Dropout_rate: 0.30000000000000004
# learning_rate: 0.055962630104591043
# Score: 1.472888469696045
# Trial summary
# Hyperparameters:
# rnn_layer_1: 120
# recurrent_dropout: 0.3
# dense_layer_1: 152
# Dropout_rate: 0.4
# learning_rate: 0.0010854128446585705
# Score: 1.4834364652633667
# Trial summary
# Hyperparameters:
# rnn_layer_1: 192
# recurrent_dropout: 0.4
# dense_layer_1: 208
# Dropout_rate: 0.30000000000000004
# learning_rate: 0.0154976703990679
# Score: 1.486486554145813
# Trial summary
# Hyperparameters:
# rnn_layer_1: 104
# recurrent_dropout: 0.3
# dense_layer_1: 80
# Dropout_rate: 0.5
# learning_rate: 0.0064748734504357745
# Score: 1.5057257413864136
# Trial summary
# Hyperparameters:
# rnn_layer_1: 48
# recurrent_dropout: 0.4
# dense_layer_1: 16
# Dropout_rate: 0.5
# learning_rate: 0.01858634561395444
# Score: 1.6144616603851318

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
# Needed for `Sequential` without specified `input_shape`.
best_model.build(input_shape=(None, 4))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 168)               29064
#
#  dense (Dense)               (None, 88)                14872
#
#  dropout (Dropout)           (None, 88)                0
#
#  dense_1 (Dense)             (None, 1)                 89
#
# =================================================================
# Total params: 44,025
# Trainable params: 44,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Bidirectional

# %%
model = Sequential()
model.add(Bidirectional(SimpleRNN(128,activation='relu',input_dim = 4)))
model.add(Dense(1,activation='linear'))
ad=optimizers.Adam(learning_rate = 0.000019397829726650643)
model.compile(optimizer = ad, loss = 'mape', metrics = ['mape'])
model_history=model.fit(trainX, trainY,validation_data=(testX,testY), batch_size = 35, epochs = 300)
# Out:
# Epoch 1/300
# 137/137 [==============================] - 5s 10ms/step - loss: 107.4727 - mape: 107.4727 - val_loss: 98.7135 - val_mape: 98.7135
# Epoch 2/300
# 137/137 [==============================] - 1s 7ms/step - loss: 78.0363 - mape: 78.0363 - val_loss: 75.0800 - val_mape: 75.0800
# Epoch 3/300
# 137/137 [==============================] - 1s 9ms/step - loss: 48.4892 - mape: 48.4892 - val_loss: 51.4545 - val_mape: 51.4545
# Epoch 4/300
# 137/137 [==============================] - 0s 3ms/step - loss: 27.9531 - mape: 27.9531 - val_loss: 35.6378 - val_mape: 35.6378
# Epoch 5/300
# 137/137 [==============================] - 0s 3ms/step - loss: 20.4302 - mape: 20.4302 - val_loss: 24.5913 - val_mape: 24.5913
# Epoch 6/300
# 137/137 [==============================] - 1s 4ms/step - loss: 16.3151 - mape: 16.3151 - val_loss: 16.6107 - val_mape: 16.6107
# Epoch 7/300
# 137/137 [==============================] - 0s 3ms/step - loss: 14.0591 - mape: 14.0591 - val_loss: 13.7892 - val_mape: 13.7892
# Epoch 8/300
# 137/137 [==============================] - 0s 3ms/step - loss: 12.2735 - mape: 12.2735 - val_loss: 11.7501 - val_mape: 11.7501
# Epoch 9/300
# 137/137 [==============================] - 0s 3ms/step - loss: 10.3666 - mape: 10.3666 - val_loss: 10.0614 - val_mape: 10.0614
# Epoch 10/300
# 137/137 [==============================] - 0s 3ms/step - loss: 8.3861 - mape: 8.3861 - val_loss: 7.8382 - val_mape: 7.8382
# Epoch 11/300
# 137/137 [==============================] - 0s 4ms/step - loss: 6.3381 - mape: 6.3381 - val_loss: 5.5160 - val_mape: 5.5160
# Epoch 12/300
# 137/137 [==============================] - 1s 4ms/step - loss: 4.2122 - mape: 4.2122 - val_loss: 3.6668 - val_mape: 3.6668
# Epoch 13/300
# 137/137 [==============================] - 1s 4ms/step - loss: 2.3198 - mape: 2.3198 - val_loss: 2.0520 - val_mape: 2.0520
# Epoch 14/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.6365 - mape: 1.6365 - val_loss: 1.7281 - val_mape: 1.7281
# Epoch 15/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.6082 - mape: 1.6082 - val_loss: 1.7080 - val_mape: 1.7080
# Epoch 16/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.6084 - mape: 1.6084 - val_loss: 1.7091 - val_mape: 1.7091
# Epoch 17/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.6023 - mape: 1.6023 - val_loss: 1.7035 - val_mape: 1.7035
# Epoch 18/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.5852 - mape: 1.5852 - val_loss: 1.6935 - val_mape: 1.6935
# Epoch 19/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.5731 - mape: 1.5731 - val_loss: 1.6777 - val_mape: 1.6777
# Epoch 20/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.5689 - mape: 1.5689 - val_loss: 1.6637 - val_mape: 1.6637
# Epoch 21/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.5579 - mape: 1.5579 - val_loss: 1.6549 - val_mape: 1.6549
# Epoch 22/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.5485 - mape: 1.5485 - val_loss: 1.6446 - val_mape: 1.6446
# Epoch 23/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.5416 - mape: 1.5416 - val_loss: 1.6370 - val_mape: 1.6370
# Epoch 24/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.5260 - mape: 1.5260 - val_loss: 1.6166 - val_mape: 1.6166
# Epoch 25/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.5091 - mape: 1.5091 - val_loss: 1.6061 - val_mape: 1.6061
# Epoch 26/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.5024 - mape: 1.5024 - val_loss: 1.5987 - val_mape: 1.5987
# Epoch 27/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4892 - mape: 1.4892 - val_loss: 1.5941 - val_mape: 1.5941
# Epoch 28/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4889 - mape: 1.4889 - val_loss: 1.5874 - val_mape: 1.5874
# Epoch 29/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4816 - mape: 1.4816 - val_loss: 1.5876 - val_mape: 1.5876
# Epoch 30/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4851 - mape: 1.4851 - val_loss: 1.5784 - val_mape: 1.5784
# Epoch 31/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4811 - mape: 1.4811 - val_loss: 1.5782 - val_mape: 1.5782
# Epoch 32/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4746 - mape: 1.4746 - val_loss: 1.5733 - val_mape: 1.5733
# Epoch 33/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4821 - mape: 1.4821 - val_loss: 1.5708 - val_mape: 1.5708
# Epoch 34/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4628 - mape: 1.4628 - val_loss: 1.5685 - val_mape: 1.5685
# Epoch 35/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.4653 - mape: 1.4653 - val_loss: 1.5875 - val_mape: 1.5875
# Epoch 36/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4635 - mape: 1.4635 - val_loss: 1.5628 - val_mape: 1.5628
# Epoch 37/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.4631 - mape: 1.4631 - val_loss: 1.5709 - val_mape: 1.5709
# Epoch 38/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4634 - mape: 1.4634 - val_loss: 1.5728 - val_mape: 1.5728
# Epoch 39/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.4565 - mape: 1.4565 - val_loss: 1.5577 - val_mape: 1.5577
# Epoch 40/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4663 - mape: 1.4663 - val_loss: 1.5549 - val_mape: 1.5549
# Epoch 41/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4512 - mape: 1.4512 - val_loss: 1.5519 - val_mape: 1.5519
# Epoch 42/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4515 - mape: 1.4515 - val_loss: 1.5516 - val_mape: 1.5516
# Epoch 43/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4552 - mape: 1.4552 - val_loss: 1.5483 - val_mape: 1.5483
# Epoch 44/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4486 - mape: 1.4486 - val_loss: 1.5496 - val_mape: 1.5496
# Epoch 45/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4469 - mape: 1.4469 - val_loss: 1.5546 - val_mape: 1.5546
# Epoch 46/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4485 - mape: 1.4485 - val_loss: 1.5499 - val_mape: 1.5499
# Epoch 47/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4442 - mape: 1.4442 - val_loss: 1.5409 - val_mape: 1.5409
# Epoch 48/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4412 - mape: 1.4412 - val_loss: 1.5457 - val_mape: 1.5457
# Epoch 49/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4407 - mape: 1.4407 - val_loss: 1.5449 - val_mape: 1.5449
# Epoch 50/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4416 - mape: 1.4416 - val_loss: 1.5351 - val_mape: 1.5351
# Epoch 51/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4351 - mape: 1.4351 - val_loss: 1.5399 - val_mape: 1.5399
# Epoch 52/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4431 - mape: 1.4431 - val_loss: 1.5309 - val_mape: 1.5309
# Epoch 53/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4369 - mape: 1.4369 - val_loss: 1.5375 - val_mape: 1.5375
# Epoch 54/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4430 - mape: 1.4430 - val_loss: 1.5321 - val_mape: 1.5321
# Epoch 55/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4385 - mape: 1.4385 - val_loss: 1.5289 - val_mape: 1.5289
# Epoch 56/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4328 - mape: 1.4328 - val_loss: 1.5356 - val_mape: 1.5356
# Epoch 57/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4285 - mape: 1.4285 - val_loss: 1.5234 - val_mape: 1.5234
# Epoch 58/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4274 - mape: 1.4274 - val_loss: 1.5374 - val_mape: 1.5374
# Epoch 59/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4277 - mape: 1.4277 - val_loss: 1.5228 - val_mape: 1.5228
# Epoch 60/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4277 - mape: 1.4277 - val_loss: 1.5340 - val_mape: 1.5340
# Epoch 61/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4221 - mape: 1.4221 - val_loss: 1.5183 - val_mape: 1.5183
# Epoch 62/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4212 - mape: 1.4212 - val_loss: 1.5208 - val_mape: 1.5208
# Epoch 63/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4290 - mape: 1.4290 - val_loss: 1.5152 - val_mape: 1.5152
# Epoch 64/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.4237 - mape: 1.4237 - val_loss: 1.5145 - val_mape: 1.5145
# Epoch 65/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4247 - mape: 1.4247 - val_loss: 1.5163 - val_mape: 1.5163
# Epoch 66/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.4174 - mape: 1.4174 - val_loss: 1.5100 - val_mape: 1.5100
# Epoch 67/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.4192 - mape: 1.4192 - val_loss: 1.5124 - val_mape: 1.5124
# Epoch 68/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4176 - mape: 1.4176 - val_loss: 1.5243 - val_mape: 1.5243
# Epoch 69/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.4154 - mape: 1.4154 - val_loss: 1.5112 - val_mape: 1.5112
# Epoch 70/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4163 - mape: 1.4163 - val_loss: 1.5059 - val_mape: 1.5059
# Epoch 71/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4138 - mape: 1.4138 - val_loss: 1.5106 - val_mape: 1.5106
# Epoch 72/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4075 - mape: 1.4075 - val_loss: 1.5051 - val_mape: 1.5051
# Epoch 73/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4100 - mape: 1.4100 - val_loss: 1.5105 - val_mape: 1.5105
# Epoch 74/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.4116 - mape: 1.4116 - val_loss: 1.5157 - val_mape: 1.5157
# Epoch 75/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4121 - mape: 1.4121 - val_loss: 1.4993 - val_mape: 1.4993
# Epoch 76/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4092 - mape: 1.4092 - val_loss: 1.5003 - val_mape: 1.5003
# Epoch 77/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4113 - mape: 1.4113 - val_loss: 1.4978 - val_mape: 1.4978
# Epoch 78/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.4112 - mape: 1.4112 - val_loss: 1.4978 - val_mape: 1.4978
# Epoch 79/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4071 - mape: 1.4071 - val_loss: 1.4990 - val_mape: 1.4990
# Epoch 80/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4068 - mape: 1.4068 - val_loss: 1.4939 - val_mape: 1.4939
# Epoch 81/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.4022 - mape: 1.4022 - val_loss: 1.4979 - val_mape: 1.4979
# Epoch 82/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.
300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3576 - mape: 1.3576 - val_loss: 1.4527 - val_mape: 1.4527
# Epoch 183/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3583 - mape: 1.3583 - val_loss: 1.4538 - val_mape: 1.4538
# Epoch 184/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3567 - mape: 1.3567 - val_loss: 1.4517 - val_mape: 1.4517
# Epoch 185/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3553 - mape: 1.3553 - val_loss: 1.4610 - val_mape: 1.4610
# Epoch 186/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3573 - mape: 1.3573 - val_loss: 1.4563 - val_mape: 1.4563
# Epoch 187/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.3555 - mape: 1.3555 - val_loss: 1.4535 - val_mape: 1.4535
# Epoch 188/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.3562 - mape: 1.3562 - val_loss: 1.4521 - val_mape: 1.4521
# Epoch 189/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3564 - mape: 1.3564 - val_loss: 1.4750 - val_mape: 1.4750
# Epoch 190/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3574 - mape: 1.3574 - val_loss: 1.4522 - val_mape: 1.4522
# Epoch 191/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3546 - mape: 1.3546 - val_loss: 1.4564 - val_mape: 1.4564
# Epoch 192/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.3587 - mape: 1.3587 - val_loss: 1.4511 - val_mape: 1.4511
# Epoch 193/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3579 - mape: 1.3579 - val_loss: 1.4513 - val_mape: 1.4513
# Epoch 194/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3557 - mape: 1.3557 - val_loss: 1.4512 - val_mape: 1.4512
# Epoch 195/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3547 - mape: 1.3547 - val_loss: 1.4553 - val_mape: 1.4553
# Epoch 196/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3545 - mape: 1.3545 - val_loss: 1.4526 - val_mape: 1.4526
# Epoch 197/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3533 - mape: 1.3533 - val_loss: 1.4564 - val_mape: 1.4564
# Epoch 198/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.3524 - mape: 1.3524 - val_loss: 1.4604 - val_mape: 1.4604
# Epoch 199/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3473 - mape: 1.3473 - val_loss: 1.4670 - val_mape: 1.4670
# Epoch 200/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3509 - mape: 1.3509 - val_loss: 1.4643 - val_mape: 1.4643
# Epoch 201/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.3514 - mape: 1.3514 - val_loss: 1.4527 - val_mape: 1.4527
# Epoch 202/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3525 - mape: 1.3525 - val_loss: 1.4558 - val_mape: 1.4558
# Epoch 203/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.3575 - mape: 1.3575 - val_loss: 1.4512 - val_mape: 1.4512
# Epoch 204/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3522 - mape: 1.3522 - val_loss: 1.4510 - val_mape: 1.4510
# Epoch 205/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3521 - mape: 1.3521 - val_loss: 1.4502 - val_mape: 1.4502
# Epoch 206/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3512 - mape: 1.3512 - val_loss: 1.4507 - val_mape: 1.4507
# Epoch 207/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3564 - mape: 1.3564 - val_loss: 1.4603 - val_mape: 1.4603
# Epoch 208/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3567 - mape: 1.3567 - val_loss: 1.4639 - val_mape: 1.4639
# Epoch 209/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3516 - mape: 1.3516 - val_loss: 1.4540 - val_mape: 1.4540
# Epoch 210/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.3540 - mape: 1.3540 - val_loss: 1.4640 - val_mape: 1.4640
# Epoch 211/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3558 - mape: 1.3558 - val_loss: 1.4652 - val_mape: 1.4652
# Epoch 212/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3499 - mape: 1.3499 - val_loss: 1.4540 - val_mape: 1.4540
# Epoch 213/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.3539 - mape: 1.3539 - val_loss: 1.4515 - val_mape: 1.4515
# Epoch 214/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3486 - mape: 1.3486 - val_loss: 1.4524 - val_mape: 1.4524
# Epoch 215/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.
300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3421 - mape: 1.3421 - val_loss: 1.4705 - val_mape: 1.4705
# Epoch 282/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3508 - mape: 1.3508 - val_loss: 1.4489 - val_mape: 1.4489
# Epoch 283/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3383 - mape: 1.3383 - val_loss: 1.4595 - val_mape: 1.4595
# Epoch 284/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3444 - mape: 1.3444 - val_loss: 1.4694 - val_mape: 1.4694
# Epoch 285/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3420 - mape: 1.3420 - val_loss: 1.4482 - val_mape: 1.4482
# Epoch 286/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3383 - mape: 1.3383 - val_loss: 1.4483 - val_mape: 1.4483
# Epoch 287/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3421 - mape: 1.3421 - val_loss: 1.4640 - val_mape: 1.4640
# Epoch 288/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3355 - mape: 1.3355 - val_loss: 1.4544 - val_mape: 1.4544
# Epoch 289/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3389 - mape: 1.3389 - val_loss: 1.4479 - val_mape: 1.4479
# Epoch 290/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.3379 - mape: 1.3379 - val_loss: 1.4502 - val_mape: 1.4502
# Epoch 291/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3392 - mape: 1.3392 - val_loss: 1.4480 - val_mape: 1.4480
# Epoch 292/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3386 - mape: 1.3386 - val_loss: 1.4488 - val_mape: 1.4488
# Epoch 293/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3362 - mape: 1.3362 - val_loss: 1.4518 - val_mape: 1.4518
# Epoch 294/300
# 137/137 [==============================] - 0s 4ms/step - loss: 1.3407 - mape: 1.3407 - val_loss: 1.4510 - val_mape: 1.4510
# Epoch 295/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3420 - mape: 1.3420 - val_loss: 1.4483 - val_mape: 1.4483
# Epoch 296/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3418 - mape: 1.3418 - val_loss: 1.4776 - val_mape: 1.4776
# Epoch 297/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3365 - mape: 1.3365 - val_loss: 1.4631 - val_mape: 1.4631
# Epoch 298/300
# 137/137 [==============================] - 0s 3ms/step - loss: 1.3390 - mape: 1.3390 - val_loss: 1.4479 - val_mape: 1.4479
# Epoch 299/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3370 - mape: 1.3370 - val_loss: 1.4481 - val_mape: 1.4481
# Epoch 300/300
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3389 - mape: 1.3389 - val_loss: 1.4492 - val_mape: 1.4492

# %%
def model_loss(history):
    plt.figure(figsize=(8,4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='upper right')
    plt.show();

# %%
train_score = model.evaluate(trainX, trainY,verbose=0)
test_score = model.evaluate(testX, testY,verbose=0)

# %%
train_predict = model.predict(trainX)
test_predict = model.predict(testX)

# invert predictions
train_predict = scaler.inverse_transform(train_predict)
trainY = scaler.inverse_transform([trainY])
test_predict = scaler.inverse_transform(test_predict)
testY = scaler.inverse_transform([testY])
print('Train MAPE : %.2f ' % (train_score[1]))
print('Test MAPE : %.2f ' % (test_score[1]))
model_loss(model_history)
# Out:
# Train MAPE : 1.33
# Test MAPE : 1.45

# %%
import seaborn as sns

# %%
def prediction_plot(testY, test_predict,look_back):
    len_prediction=[x for x in range(4771,5298)]
    plt.plot(trainY.reshape(-1,))
    plt.plot(len_prediction, testY.reshape(-1,), marker='.', label='actual')
    plt.plot(len_prediction, test_predict, 'g', label="prediction")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Units', size=15)
    plt.xlabel('Time step', size=15)
    plt.legend(fontsize=15)
    plt.show()

# %%
test_predict = model.predict(testX)
test_predict = scaler.inverse_transform(test_predict)
prediction_plot(testY, test_predict,look_back)
