# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn.metrics import mean_absolute_error as mae
from pandas.tseries.offsets import BDay

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14494480343520806349
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11320098816
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1229225032833911937
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
#  xla_global_id: 416903419]

# %%
df_main = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Stock Market/RELIANCE.csv')
df_main.head()
# Out:
#          Date    Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0  2000-01-03  RELIANCE     EQ  ...     NaN                 NaN          NaN
# 1  2000-01-04  RELIANCE     EQ  ...     NaN                 NaN          NaN
# 2  2000-01-05  RELIANCE     EQ  ...     NaN                 NaN          NaN
# 3  2000-01-06  RELIANCE     EQ  ...     NaN                 NaN          NaN
# 4  2000-01-07  RELIANCE     EQ  ...     NaN                 NaN          NaN
#
# [5 rows x 15 columns]

# %%
df_main.drop(['Trades','Deliverable Volume','%Deliverble'],axis=1,inplace=True)

# %%
df_main.shape
# Out:
# (5306, 12)

# %%
time = pd.date_range(start='2000-01-03',periods=5306,freq=BDay())
df_main['time_stamp'] = pd.DataFrame(time)
df_main.drop(['Date'],axis=1,inplace=True)
df_main = df_main.set_index('time_stamp')

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5306 entries, 2000-01-03 to 2020-05-04
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      5306 non-null   object
#  1   Series      5306 non-null   object
#  2   Prev Close  5306 non-null   float64
#  3   Open        5306 non-null   float64
#  4   High        5306 non-null   float64
#  5   Low         5306 non-null   float64
#  6   Last        5306 non-null   float64
#  7   Close       5306 non-null   float64
#  8   VWAP        5306 non-null   float64
#  9   Volume      5306 non-null   int64
#  10  Turnover    5306 non-null   float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 497.4+ KB

# %%
df = df_main[['Close']]

# %%
df.head()
# Out:
#              Close
# time_stamp
# 2000-01-03  251.70
# 2000-01-04  271.85
# 2000-01-05  282.50
# 2000-01-06  294.35
# 2000-01-07  314.55

# %%
df.tail()
# Out:
#               Close
# time_stamp
# 2020-04-28  1937.85
# 2020-04-29  1988.65
# 2020-04-30  1997.30
# 2020-05-01  2024.05
# 2020-05-04  1994.50

# %%
plt.rcParams['figure.figsize'] = [15,8]

# %%
plt.plot(df,color='black')
plt.title('Daily Reliance Stock Price',fontsize=20)
plt.xlabel('Date',fontsize=15)
plt.ylabel('Units',fontsize=15)
plt.show()

# %%
def convert2matrix(data_arr, look_back):
    X, Y =[], []
    for i in range(len(data_arr)-look_back):
        d=i+look_back  
        X.append(data_arr[i:d,0])
        Y.append(data_arr[d,0])
    return np.array(X), np.array(Y)

# %%
from sklearn.preprocessing import MinMaxScaler
#create numpy.ndarray 
df['Close'] = df['Close'].astype(np.float32)
df_arr = df.values
df_arr = np.reshape(df_arr, (-1, 1))
scaler = MinMaxScaler(feature_range=(0.1, 1))
df_arr = scaler.fit_transform(df_arr)

# %%
#Split data set into testing dataset and train dataset
train_size = 4775
train, test =df_arr[0:train_size,:], df_arr[train_size:len(df_arr),:]
# setup look_back window 
look_back = 4
#convert dataset into right shape in order to input into the DNN
trainX, trainY = convert2matrix(train, look_back)
testX, testY = convert2matrix(test, look_back)
# reshape input to be [samples, window size, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (4771, 1, 4)
# (4771,)
# (527, 1, 4)
# (527,)

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 2.8 MB/s

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,SimpleRNN
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.layers import Flatten
import matplotlib.pyplot as plt

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(LSTM(hp.Int('lstm_layer_1',min_value=8,max_value=256,step=8), activation="relu", input_shape=(1,look_back),recurrent_dropout = hp.Choice("recurrent_dropout",[0.2,0.3,0.4],default=0.2)))
    model.add(Dense(hp.Int('dense_layer_1',min_value=8,max_value=256,step=8),activation="relu"))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
             hp.Float('learning_rate', min_value=1e-3, max_value=1e-1, sampling="log")),
        loss='mape',
        metrics=['mape'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mape',
    max_trials=10,
    executions_per_trial=1,
    directory='project',
    project_name='loa_em_4')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 5
# lstm_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# recurrent_dropout (Choice)
# {'default': 0.2, 'conditions': [], 'values': [0.2, 0.3, 0.4], 'ordered': True}
# dense_layer_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# Dropout_rate (Float)
# {'default': 0.0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.5, 'step': 0.1, 'sampling': None}
# learning_rate (Float)
# {'default': 0.001, 'conditions': [], 'min_value': 0.001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}

# %%
tuner.search(trainX, trainY,
             epochs=200,
             batch_size=35,
             validation_data=(testX, testY))
# Out:
# Trial 10 Complete [00h 02m 24s]
# val_mape: 1.4890766143798828
#
# Best val_mape So Far: 1.4428285360336304
# Total elapsed time: 00h 36m 18s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/loa_em_4
# Showing 10 best trials
# Objective(name='val_mape', direction='min')
# Trial summary
# Hyperparameters:
# lstm_layer_1: 104
# recurrent_dropout: 0.4
# dense_layer_1: 104
# Dropout_rate: 0.1
# learning_rate: 0.0017011092817375538
# Score: 1.4428285360336304
# Trial summary
# Hyperparameters:
# lstm_layer_1: 184
# recurrent_dropout: 0.3
# dense_layer_1: 192
# Dropout_rate: 0.2
# learning_rate: 0.0011616898171829461
# Score: 1.4454517364501953
# Trial summary
# Hyperparameters:
# lstm_layer_1: 224
# recurrent_dropout: 0.2
# dense_layer_1: 208
# Dropout_rate: 0.0
# learning_rate: 0.06461395303882178
# Score: 1.449363112449646
# Trial summary
# Hyperparameters:
# lstm_layer_1: 120
# recurrent_dropout: 0.2
# dense_layer_1: 248
# Dropout_rate: 0.4
# learning_rate: 0.00269263370697111
# Score: 1.4511526823043823
# Trial summary
# Hyperparameters:
# lstm_layer_1: 24
# recurrent_dropout: 0.2
# dense_layer_1: 160
# Dropout_rate: 0.2
# learning_rate: 0.001372259330713521
# Score: 1.4558237791061401
# Trial summary
# Hyperparameters:
# lstm_layer_1: 200
# recurrent_dropout: 0.2
# dense_layer_1: 200
# Dropout_rate: 0.30000000000000004
# learning_rate: 0.05565016911877951
# Score: 1.4565733671188354
# Trial summary
# Hyperparameters:
# lstm_layer_1: 168
# recurrent_dropout: 0.3
# dense_layer_1: 224
# Dropout_rate: 0.4
# learning_rate: 0.07307800174947307
# Score: 1.457919716835022
# Trial summary
# Hyperparameters:
# lstm_layer_1: 184
# recurrent_dropout: 0.2
# dense_layer_1: 160
# Dropout_rate: 0.1
# learning_rate: 0.04596970069717873
# Score: 1.4639955759048462
# Trial summary
# Hyperparameters:
# lstm_layer_1: 104
# recurrent_dropout: 0.3
# dense_layer_1: 136
# Dropout_rate: 0.4
# learning_rate: 0.024186545482647745
# Score: 1.4866214990615845
# Trial summary
# Hyperparameters:
# lstm_layer_1: 8
# recurrent_dropout: 0.4
# dense_layer_1: 104
# Dropout_rate: 0.5
# learning_rate: 0.004108406797282931
# Score: 1.4890766143798828

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
# Needed for `Sequential` without specified `input_shape`.
best_model.build(input_shape=(None, 4))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 104)               45344
#
#  dense (Dense)               (None, 104)               10920
#
#  dropout (Dropout)           (None, 104)               0
#
#  dense_1 (Dense)             (None, 1)                 105
#
# =================================================================
# Total params: 56,369
# Trainable params: 56,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(LSTM(104,activation='relu',input_dim = 4,recurrent_dropout=0.3))
model.add(Dense(104,activation='relu'))
model.add(Dense(1,activation='linear'))
ad=optimizers.Adam(learning_rate = 0.000017011092817375538)
model.compile(optimizer = ad, loss = 'mape', metrics = ['mape'])
model_history=model.fit(trainX, trainY,validation_data=(testX,testY), batch_size = 35, epochs = 300)
# Out:
# Epoch 1/300
# 137/137 [==============================] - 4s 8ms/step - loss: 93.3258 - mape: 93.3258 - val_loss: 91.4960 - val_mape: 91.4960
# Epoch 2/300
# 137/137 [==============================] - 1s 6ms/step - loss: 82.8712 - mape: 82.8712 - val_loss: 84.0406 - val_mape: 84.0406
# Epoch 3/300
# 137/137 [==============================] - 1s 5ms/step - loss: 71.3665 - mape: 71.3665 - val_loss: 75.6498 - val_mape: 75.6498
# Epoch 4/300
# 137/137 [==============================] - 1s 6ms/step - loss: 58.0554 - mape: 58.0554 - val_loss: 65.6832 - val_mape: 65.6832
# Epoch 5/300
# 137/137 [==============================] - 1s 6ms/step - loss: 43.2435 - mape: 43.2435 - val_loss: 55.1618 - val_mape: 55.1618
# Epoch 6/300
# 137/137 [==============================] - 1s 5ms/step - loss: 33.4502 - mape: 33.4502 - val_loss: 47.4119 - val_mape: 47.4119
# Epoch 7/300
# 137/137 [==============================] - 1s 6ms/step - loss: 29.0079 - mape: 29.0079 - val_loss: 40.5036 - val_mape: 40.5036
# Epoch 8/300
# 137/137 [==============================] - 1s 6ms/step - loss: 25.6420 - mape: 25.6420 - val_loss: 34.2950 - val_mape: 34.2950
# Epoch 9/300
# 137/137 [==============================] - 1s 6ms/step - loss: 23.3613 - mape: 23.3613 - val_loss: 28.9767 - val_mape: 28.9767
# Epoch 10/300
# 137/137 [==============================] - 1s 6ms/step - loss: 21.3133 - mape: 21.3133 - val_loss: 23.5509 - val_mape: 23.5509
# Epoch 11/300
# 137/137 [==============================] - 1s 6ms/step - loss: 19.5794 - mape: 19.5794 - val_loss: 19.8338 - val_mape: 19.8338
# Epoch 12/300
# 137/137 [==============================] - 1s 5ms/step - loss: 18.1416 - mape: 18.1416 - val_loss: 17.5308 - val_mape: 17.5308
# Epoch 13/300
# 137/137 [==============================] - 1s 6ms/step - loss: 16.6632 - mape: 16.6632 - val_loss: 15.7435 - val_mape: 15.7435
# Epoch 14/300
# 137/137 [==============================] - 1s 6ms/step - loss: 15.0395 - mape: 15.0395 - val_loss: 13.4128 - val_mape: 13.4128
# Epoch 15/300
# 137/137 [==============================] - 1s 5ms/step - loss: 13.2593 - mape: 13.2593 - val_loss: 11.3725 - val_mape: 11.3725
# Epoch 16/300
# 137/137 [==============================] - 1s 5ms/step - loss: 11.3068 - mape: 11.3068 - val_loss: 9.2291 - val_mape: 9.2291
# Epoch 17/300
# 137/137 [==============================] - 1s 5ms/step - loss: 9.1438 - mape: 9.1438 - val_loss: 7.0165 - val_mape: 7.0165
# Epoch 18/300
# 137/137 [==============================] - 1s 5ms/step - loss: 6.8707 - mape: 6.8707 - val_loss: 4.5169 - val_mape: 4.5169
# Epoch 19/300
# 137/137 [==============================] - 1s 5ms/step - loss: 4.6625 - mape: 4.6625 - val_loss: 2.5951 - val_mape: 2.5951
# Epoch 20/300
# 137/137 [==============================] - 1s 5ms/step - loss: 2.9821 - mape: 2.9821 - val_loss: 2.2365 - val_mape: 2.2365
# Epoch 21/300
# 137/137 [==============================] - 1s 5ms/step - loss: 2.2456 - mape: 2.2456 - val_loss: 2.4171 - val_mape: 2.4171
# Epoch 22/300
# 137/137 [==============================] - 1s 5ms/step - loss: 2.0924 - mape: 2.0924 - val_loss: 2.3844 - val_mape: 2.3844
# Epoch 23/300
# 137/137 [==============================] - 1s 5ms/step - loss: 2.0307 - mape: 2.0307 - val_loss: 2.2953 - val_mape: 2.2953
# Epoch 24/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.9904 - mape: 1.9904 - val_loss: 2.2239 - val_mape: 2.2239
# Epoch 25/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.9680 - mape: 1.9680 - val_loss: 2.1867 - val_mape: 2.1867
# Epoch 26/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.9450 - mape: 1.9450 - val_loss: 2.1446 - val_mape: 2.1446
# Epoch 27/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.9322 - mape: 1.9322 - val_loss: 2.1512 - val_mape: 2.1512
# Epoch 28/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.9196 - mape: 1.9196 - val_loss: 2.1084 - val_mape: 2.1084
# Epoch 29/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.9191 - mape: 1.9191 - val_loss: 2.1058 - val_mape: 2.1058
# Epoch 30/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.9066 - mape: 1.9066 - val_loss: 2.0950 - val_mape: 2.0950
# Epoch 31/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.9018 - mape: 1.9018 - val_loss: 2.1025 - val_mape: 2.1025
# Epoch 32/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8970 - mape: 1.8970 - val_loss: 2.0787 - val_mape: 2.0787
# Epoch 33/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8884 - mape: 1.8884 - val_loss: 2.0640 - val_mape: 2.0640
# Epoch 34/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8882 - mape: 1.8882 - val_loss: 2.0565 - val_mape: 2.0565
# Epoch 35/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8798 - mape: 1.8798 - val_loss: 2.0494 - val_mape: 2.0494
# Epoch 36/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8758 - mape: 1.8758 - val_loss: 2.0475 - val_mape: 2.0475
# Epoch 37/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8700 - mape: 1.8700 - val_loss: 2.0310 - val_mape: 2.0310
# Epoch 38/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8736 - mape: 1.8736 - val_loss: 2.0277 - val_mape: 2.0277
# Epoch 39/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8633 - mape: 1.8633 - val_loss: 2.0241 - val_mape: 2.0241
# Epoch 40/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8608 - mape: 1.8608 - val_loss: 2.0224 - val_mape: 2.0224
# Epoch 41/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8573 - mape: 1.8573 - val_loss: 2.0068 - val_mape: 2.0068
# Epoch 42/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8539 - mape: 1.8539 - val_loss: 2.0048 - val_mape: 2.0048
# Epoch 43/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8500 - mape: 1.8500 - val_loss: 1.9933 - val_mape: 1.9933
# Epoch 44/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8459 - mape: 1.8459 - val_loss: 1.9920 - val_mape: 1.9920
# Epoch 45/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8462 - mape: 1.8462 - val_loss: 1.9976 - val_mape: 1.9976
# Epoch 46/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8454 - mape: 1.8454 - val_loss: 1.9976 - val_mape: 1.9976
# Epoch 47/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8371 - mape: 1.8371 - val_loss: 1.9856 - val_mape: 1.9856
# Epoch 48/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8345 - mape: 1.8345 - val_loss: 1.9686 - val_mape: 1.9686
# Epoch 49/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8353 - mape: 1.8353 - val_loss: 1.9824 - val_mape: 1.9824
# Epoch 50/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8275 - mape: 1.8275 - val_loss: 1.9584 - val_mape: 1.9584
# Epoch 51/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8337 - mape: 1.8337 - val_loss: 1.9673 - val_mape: 1.9673
# Epoch 52/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.8277 - mape: 1.8277 - val_loss: 1.9518 - val_mape: 1.9518
# Epoch 53/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.8238 - mape: 1.8238 - val_loss: 1.9481 - val_mape: 1.9481
# Epoch 54/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.8182 - mape: 1.8182 - val_loss: 1.9486 - val_mape: 1.9486
# Epoch 55/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8175 - mape: 1.8175 - val_loss: 1.9581 - val_mape: 1.9581
# Epoch 56/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.8171 - mape: 1.8171 - val_loss: 1.9392 - val_mape: 1.9392
# Epoch 57/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.8082 - mape: 1.8082 - val_loss: 1.9366 - val_mape: 1.9366
# Epoch 58/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8116 - mape: 1.8116 - val_loss: 1.9438 - val_mape: 1.9438
# Epoch 59/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8084 - mape: 1.8084 - val_loss: 1.9298 - val_mape: 1.9298
# Epoch 60/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8033 - mape: 1.8033 - val_loss: 1.9244 - val_mape: 1.9244
# Epoch 61/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.8061 - mape: 1.8061 - val_loss: 1.9354 - val_mape: 1.9354
# Epoch 62/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.8090 - mape: 1.8090 - val_loss: 1.9270 - val_mape: 1.9270
# Epoch 63/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7944 - mape: 1.7944 - val_loss: 1.9350 - val_mape: 1.9350
# Epoch 64/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7971 - mape: 1.7971 - val_loss: 1.9208 - val_mape: 1.9208
# Epoch 65/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.7977 - mape: 1.7977 - val_loss: 1.9080 - val_mape: 1.9080
# Epoch 66/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7923 - mape: 1.7923 - val_loss: 1.9167 - val_mape: 1.9167
# Epoch 67/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.7919 - mape: 1.7919 - val_loss: 1.9160 - val_mape: 1.9160
# Epoch 68/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7935 - mape: 1.7935 - val_loss: 1.9014 - val_mape: 1.9014
# Epoch 69/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.7882 - mape: 1.7882 - val_loss: 1.8992 - val_mape: 1.8992
# Epoch 70/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7846 - mape: 1.7846 - val_loss: 1.9030 - val_mape: 1.9030
# Epoch 71/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7845 - mape: 1.7845 - val_loss: 1.8961 - val_mape: 1.8961
# Epoch 72/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7819 - mape: 1.7819 - val_loss: 1.8949 - val_mape: 1.8949
# Epoch 73/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7822 - mape: 1.7822 - val_loss: 1.8936 - val_mape: 1.8936
# Epoch 74/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7769 - mape: 1.7769 - val_loss: 1.8898 - val_mape: 1.8898
# Epoch 75/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7776 - mape: 1.7776 - val_loss: 1.9020 - val_mape: 1.9020
# Epoch 76/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7773 - mape: 1.7773 - val_loss: 1.9163 - val_mape: 1.9163
# Epoch 77/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7708 - mape: 1.7708 - val_loss: 1.8882 - val_mape: 1.8882
# Epoch 78/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7727 - mape: 1.7727 - val_loss: 1.8942 - val_mape: 1.8942
# Epoch 79/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7698 - mape: 1.7698 - val_loss: 1.9051 - val_mape: 1.9051
# Epoch 80/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7660 - mape: 1.7660 - val_loss: 1.8914 - val_mape: 1.8914
# Epoch 81/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7695 - mape: 1.7695 - val_loss: 1.8734 - val_mape: 1.8734
# Epoch 82/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.7627 - mape: 1.7627 - val_loss: 1.8851 - val_mape: 1.8851
# Epoch 83/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7586 - mape: 1.7586 - val_loss: 1.8767 - val_mape: 1.8767
# Epoch 84/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7647 - mape: 1.7647 - val_loss: 1.8845 - val_mape: 1.8845
# Epoch 85/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7655 - mape: 1.7655 - val_loss: 1.8690 - val_mape: 1.8690
# Epoch 86/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7605 - mape: 1.7605 - val_loss: 1.8668 - val_mape: 1.8668
# Epoch 87/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7551 - mape: 1.7551 - val_loss: 1.8627 - val_mape: 1.8627
# Epoch 88/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7528 - mape: 1.7528 - val_loss: 1.8639 - val_mape: 1.8639
# Epoch 89/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7590 - mape: 1.7590 - val_loss: 1.8571 - val_mape: 1.8571
# Epoch 90/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.7497 - mape: 1.7497 - val_loss: 1.8578 - val_mape: 1.8578
# Epoch 91/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7468 - mape: 1.7468 - val_loss: 1.8621 - val_mape: 1.8621
# Epoch 92/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7418 - mape: 1.7418 - val_loss: 1.8483 - val_mape: 1.8483
# Epoch 93/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7461 - mape: 1.7461 - val_loss: 1.8461 - val_mape: 1.8461
# Epoch 94/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7433 - mape: 1.7433 - val_loss: 1.8463 - val_mape: 1.8463
# Epoch 95/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7420 - mape: 1.7420 - val_loss: 1.8449 - val_mape: 1.8449
# Epoch 96/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7382 - mape: 1.7382 - val_loss: 1.8399 - val_mape: 1.8399
# Epoch 97/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7381 - mape: 1.7381 - val_loss: 1.8577 - val_mape: 1.8577
# Epoch 98/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7402 - mape: 1.7402 - val_loss: 1.8542 - val_mape: 1.8542
# Epoch 99/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7331 - mape: 1.7331 - val_loss: 1.8352 - val_mape: 1.8352
# Epoch 100/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.7377 - mape: 1.7377 - val_loss: 1.8341 - val_mape: 1.8341
# Epoch 101/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7272 - mape: 1.7272 - val_loss: 1.8382 - val_mape: 1.8382
# Epoch 102/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7313 - mape: 1.7313 - val_loss: 1.8438 - val_mape: 1.8438
# Epoch 103/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7256 - mape: 1.7256 - val_loss: 1.8509 - val_mape: 1.8509
# Epoch 104/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7274 - mape: 1.7274 - val_loss: 1.8266 - val_mape: 1.8266
# Epoch 105/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7228 - mape: 1.7228 - val_loss: 1.8262 - val_mape: 1.8262
# Epoch 106/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7314 - mape: 1.7314 - val_loss: 1.8338 - val_mape: 1.8338
# Epoch 107/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7229 - mape: 1.7229 - val_loss: 1.8195 - val_mape: 1.8195
# Epoch 108/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.7190 - mape: 1.7190 - val_loss: 1.8171 - val_mape: 1.8171
# Epoch 109/300
# 137/137 [==============================] - 1s 5ms/step - loss: 1.7213 - mape: 1.7213 - val_loss: 1.8325 - val_mape: 1.8325
# Epoch 110/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7186 - mape: 1.7186 - val_loss: 1.8161 - val_mape: 1.8161
# Epoch 111/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7164 - mape: 1.7164 - val_loss: 1.8117 - val_mape: 1.8117
# Epoch 112/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.7174 - mape: 1.7174 - val_loss: 1.8285 - val_mape: 1.8285
# Epoch 113/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.
300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5706 - mape: 1.5706 - val_loss: 1.6690 - val_mape: 1.6690
# Epoch 214/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5671 - mape: 1.5671 - val_loss: 1.6575 - val_mape: 1.6575
# Epoch 215/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5721 - mape: 1.5721 - val_loss: 1.6673 - val_mape: 1.6673
# Epoch 216/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5646 - mape: 1.5646 - val_loss: 1.6538 - val_mape: 1.6538
# Epoch 217/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5677 - mape: 1.5677 - val_loss: 1.6554 - val_mape: 1.6554
# Epoch 218/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5668 - mape: 1.5668 - val_loss: 1.6526 - val_mape: 1.6526
# Epoch 219/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5627 - mape: 1.5627 - val_loss: 1.6503 - val_mape: 1.6503
# Epoch 220/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5614 - mape: 1.5614 - val_loss: 1.6551 - val_mape: 1.6551
# Epoch 221/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5623 - mape: 1.5623 - val_loss: 1.6478 - val_mape: 1.6478
# Epoch 222/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5595 - mape: 1.5595 - val_loss: 1.6570 - val_mape: 1.6570
# Epoch 223/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5525 - mape: 1.5525 - val_loss: 1.6475 - val_mape: 1.6475
# Epoch 224/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5517 - mape: 1.5517 - val_loss: 1.6428 - val_mape: 1.6428
# Epoch 225/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5573 - mape: 1.5573 - val_loss: 1.6431 - val_mape: 1.6431
# Epoch 226/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5527 - mape: 1.5527 - val_loss: 1.6517 - val_mape: 1.6517
# Epoch 227/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5529 - mape: 1.5529 - val_loss: 1.6575 - val_mape: 1.6575
# Epoch 228/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5521 - mape: 1.5521 - val_loss: 1.6464 - val_mape: 1.6464
# Epoch 229/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5527 - mape: 1.5527 - val_loss: 1.6369 - val_mape: 1.6369
# Epoch 230/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5484 - mape: 1.5484 - val_loss: 1.6419 - val_mape: 1.6419
# Epoch 231/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5466 - mape: 1.5466 - val_loss: 1.6517 - val_mape: 1.6517
# Epoch 232/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5427 - mape: 1.5427 - val_loss: 1.6867 - val_mape: 1.6867
# Epoch 233/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5460 - mape: 1.5460 - val_loss: 1.6424 - val_mape: 1.6424
# Epoch 234/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5395 - mape: 1.5395 - val_loss: 1.6306 - val_mape: 1.6306
# Epoch 235/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5419 - mape: 1.5419 - val_loss: 1.6307 - val_mape: 1.6307
# Epoch 236/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5436 - mape: 1.5436 - val_loss: 1.6433 - val_mape: 1.6433
# Epoch 237/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5345 - mape: 1.5345 - val_loss: 1.6355 - val_mape: 1.6355
# Epoch 238/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5408 - mape: 1.5408 - val_loss: 1.6272 - val_mape: 1.6272
# Epoch 239/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5336 - mape: 1.5336 - val_loss: 1.6284 - val_mape: 1.6284
# Epoch 240/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5378 - mape: 1.5378 - val_loss: 1.6232 - val_mape: 1.6232
# Epoch 241/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5317 - mape: 1.5317 - val_loss: 1.6262 - val_mape: 1.6262
# Epoch 242/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5338 - mape: 1.5338 - val_loss: 1.6286 - val_mape: 1.6286
# Epoch 243/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5314 - mape: 1.5314 - val_loss: 1.6189 - val_mape: 1.6189
# Epoch 244/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5320 - mape: 1.5320 - val_loss: 1.6195 - val_mape: 1.6195
# Epoch 245/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5315 - mape: 1.5315 - val_loss: 1.6384 - val_mape: 1.6384
# Epoch 246/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5256 - mape: 1.5256 - val_loss: 1.6233 - val_mape: 1.6233
# Epoch 247/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5288 - mape: 1.5288 - val_loss: 1.6279 - val_mape: 1.6279
# Epoch 248/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5333 - mape: 1.5333 - val_loss: 1.6150 - val_mape: 1.6150
# Epoch 249/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5243 - mape: 1.5243 - val_loss: 1.6120 - val_mape: 1.6120
# Epoch 250/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5217 - mape: 1.5217 - val_loss: 1.6116 - val_mape: 1.6116
# Epoch 251/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5206 - mape: 1.5206 - val_loss: 1.6264 - val_mape: 1.6264
# Epoch 252/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5309 - mape: 1.5309 - val_loss: 1.6303 - val_mape: 1.6303
# Epoch 253/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5170 - mape: 1.5170 - val_loss: 1.6159 - val_mape: 1.6159
# Epoch 254/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5160 - mape: 1.5160 - val_loss: 1.6076 - val_mape: 1.6076
# Epoch 255/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5139 - mape: 1.5139 - val_loss: 1.6249 - val_mape: 1.6249
# Epoch 256/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5156 - mape: 1.5156 - val_loss: 1.6162 - val_mape: 1.6162
# Epoch 257/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5172 - mape: 1.5172 - val_loss: 1.6150 - val_mape: 1.6150
# Epoch 258/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5151 - mape: 1.5151 - val_loss: 1.6024 - val_mape: 1.6024
# Epoch 259/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5098 - mape: 1.5098 - val_loss: 1.6179 - val_mape: 1.6179
# Epoch 260/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5201 - mape: 1.5201 - val_loss: 1.6011 - val_mape: 1.6011
# Epoch 261/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5095 - mape: 1.5095 - val_loss: 1.6027 - val_mape: 1.6027
# Epoch 262/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5090 - mape: 1.5090 - val_loss: 1.5982 - val_mape: 1.5982
# Epoch 263/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5040 - mape: 1.5040 - val_loss: 1.5964 - val_mape: 1.5964
# Epoch 264/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5045 - mape: 1.5045 - val_loss: 1.6001 - val_mape: 1.6001
# Epoch 265/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5025 - mape: 1.5025 - val_loss: 1.5975 - val_mape: 1.5975
# Epoch 266/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5019 - mape: 1.5019 - val_loss: 1.5930 - val_mape: 1.5930
# Epoch 267/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5039 - mape: 1.5039 - val_loss: 1.5945 - val_mape: 1.5945
# Epoch 268/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5041 - mape: 1.5041 - val_loss: 1.6037 - val_mape: 1.6037
# Epoch 269/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.5007 - mape: 1.5007 - val_loss: 1.5950 - val_mape: 1.5950
# Epoch 270/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4977 - mape: 1.4977 - val_loss: 1.5907 - val_mape: 1.5907
# Epoch 271/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4998 - mape: 1.4998 - val_loss: 1.5924 - val_mape: 1.5924
# Epoch 272/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4989 - mape: 1.4989 - val_loss: 1.5929 - val_mape: 1.5929
# Epoch 273/300
# 137/137 [==============================] - 1s 7ms/step - loss: 1.4963 - mape: 1.4963 - val_loss: 1.5851 - val_mape: 1.5851
# Epoch 274/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4985 - mape: 1.4985 - val_loss: 1.5849 - val_mape: 1.5849
# Epoch 275/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4957 - mape: 1.4957 - val_loss: 1.6100 - val_mape: 1.6100
# Epoch 276/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4941 - mape: 1.4941 - val_loss: 1.5862 - val_mape: 1.5862
# Epoch 277/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4943 - mape: 1.4943 - val_loss: 1.5839 - val_mape: 1.5839
# Epoch 278/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4877 - mape: 1.4877 - val_loss: 1.5855 - val_mape: 1.5855
# Epoch 279/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4853 - mape: 1.4853 - val_loss: 1.5987 - val_mape: 1.5987
# Epoch 280/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4874 - mape: 1.4874 - val_loss: 1.5777 - val_mape: 1.5777
# Epoch 281/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4877 - mape: 1.4877 - val_loss: 1.5811 - val_mape: 1.5811
# Epoch 282/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4866 - mape: 1.4866 - val_loss: 1.5784 - val_mape: 1.5784
# Epoch 283/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4870 - mape: 1.4870 - val_loss: 1.5761 - val_mape: 1.5761
# Epoch 284/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4821 - mape: 1.4821 - val_loss: 1.5751 - val_mape: 1.5751
# Epoch 285/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4816 - mape: 1.4816 - val_loss: 1.5759 - val_mape: 1.5759
# Epoch 286/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4786 - mape: 1.4786 - val_loss: 1.5744 - val_mape: 1.5744
# Epoch 287/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4792 - mape: 1.4792 - val_loss: 1.5773 - val_mape: 1.5773
# Epoch 288/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4834 - mape: 1.4834 - val_loss: 1.5783 - val_mape: 1.5783
# Epoch 289/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4833 - mape: 1.4833 - val_loss: 1.5903 - val_mape: 1.5903
# Epoch 290/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4774 - mape: 1.4774 - val_loss: 1.5697 - val_mape: 1.5697
# Epoch 291/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4755 - mape: 1.4755 - val_loss: 1.5683 - val_mape: 1.5683
# Epoch 292/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4730 - mape: 1.4730 - val_loss: 1.5968 - val_mape: 1.5968
# Epoch 293/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4737 - mape: 1.4737 - val_loss: 1.5676 - val_mape: 1.5676
# Epoch 294/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4721 - mape: 1.4721 - val_loss: 1.5643 - val_mape: 1.5643
# Epoch 295/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4731 - mape: 1.4731 - val_loss: 1.5640 - val_mape: 1.5640
# Epoch 296/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4709 - mape: 1.4709 - val_loss: 1.5630 - val_mape: 1.5630
# Epoch 297/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4674 - mape: 1.4674 - val_loss: 1.5808 - val_mape: 1.5808
# Epoch 298/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4680 - mape: 1.4680 - val_loss: 1.5641 - val_mape: 1.5641
# Epoch 299/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4725 - mape: 1.4725 - val_loss: 1.5623 - val_mape: 1.5623
# Epoch 300/300
# 137/137 [==============================] - 1s 6ms/step - loss: 1.4652 - mape: 1.4652 - val_loss: 1.5619 - val_mape: 1.5619

# %%
def model_loss(history):
    plt.figure(figsize=(8,4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='upper right')
    plt.show();

# %%
train_score = model.evaluate(trainX, trainY,verbose=0)
test_score = model.evaluate(testX, testY,verbose=0)

# %%
train_predict = model.predict(trainX)
test_predict = model.predict(testX)

# invert predictions
train_predict = scaler.inverse_transform(train_predict)
trainY = scaler.inverse_transform([trainY])
test_predict = scaler.inverse_transform(test_predict)
testY = scaler.inverse_transform([testY])
print('Train MAPE : %.2f ' % (train_score[1]))
print('Test MAPE : %.2f ' % (test_score[1]))
model_loss(model_history)
# Out:
# Train MAPE : 1.48
# Test MAPE : 1.56

# %%
import seaborn as sns

# %%
def prediction_plot(testY, test_predict,look_back):
    len_prediction=[x for x in range(4771,5298)]
    plt.plot(trainY.reshape(-1,))
    plt.plot(len_prediction, testY.reshape(-1,), marker='.', label='actual')
    plt.plot(len_prediction, test_predict, 'g', label="prediction")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Units', size=15)
    plt.xlabel('Time step', size=15)
    plt.legend(fontsize=15)
    plt.show()

# %%
test_predict = model.predict(testX)
test_predict = scaler.inverse_transform(test_predict)
prediction_plot(testY, test_predict,look_back)
